# %% [markdown]
# # MELT FUNC

# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('C:/Users/HP/Downloads/weather_by_cities.csv')
data
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df=pd.melt(data, id_vars=['city'])
df
# Out:
#         city     variable     value
# 0   new york          day  1/1/2017
# 1   new york          day  1/2/2017
# 2   new york          day  1/3/2017
# 3   new york          day  1/4/2017
# 4     mumbai          day  1/1/2017
# 5     mumbai          day  1/2/2017
# 6     mumbai          day  1/3/2017
# 7     mumbai          day  1/4/2017
# 8      paris          day  1/1/2017
# 9      paris          day  1/2/2017
# 10     paris          day  1/3/2017
# 11     paris          day  1/4/2017
# 12  new york  temperature        32
# 13  new york  temperature        36
# 14  new york  temperature        28
# 15  new york  temperature        33
# 16    mumbai  temperature        90
# 17    mumbai  temperature        85
# 18    mumbai  temperature        87
# 19    mumbai  temperature        92
# 20     paris  temperature        45
# 21     paris  temperature        50
# 22     paris  temperature        54
# 23     paris  temperature        42
# 24  new york    windspeed         6
# ...

# %%
df=pd.melt(data, id_vars=['temperature'])
df
# Out:
#     temperature   variable     value
# 0            32        day  1/1/2017
# 1            36        day  1/2/2017
# 2            28        day  1/3/2017
# 3            33        day  1/4/2017
# 4            90        day  1/1/2017
# 5            85        day  1/2/2017
# 6            87        day  1/3/2017
# 7            92        day  1/4/2017
# 8            45        day  1/1/2017
# 9            50        day  1/2/2017
# 10           54        day  1/3/2017
# 11           42        day  1/4/2017
# 12           32       city  new york
# 13           36       city  new york
# 14           28       city  new york
# 15           33       city  new york
# 16           90       city    mumbai
# 17           85       city    mumbai
# 18           87       city    mumbai
# 19           92       city    mumbai
# 20           45       city     paris
# 21           50       city     paris
# 22           54       city     paris
# 23           42       city     paris
# ...

# %%
df=pd.melt(data, id_vars=['event'])
df
# Out:
#      event     variable     value
# 0     Rain          day  1/1/2017
# 1    Sunny          day  1/2/2017
# 2     Snow          day  1/3/2017
# 3    Sunny          day  1/4/2017
# 4    Sunny          day  1/1/2017
# 5      Fog          day  1/2/2017
# 6      Fog          day  1/3/2017
# 7     Rain          day  1/4/2017
# 8    Sunny          day  1/1/2017
# 9   Cloudy          day  1/2/2017
# 10  Cloudy          day  1/3/2017
# 11  Cloudy          day  1/4/2017
# 12    Rain         city  new york
# 13   Sunny         city  new york
# 14    Snow         city  new york
# 15   Sunny         city  new york
# 16   Sunny         city    mumbai
# 17     Fog         city    mumbai
# 18     Fog         city    mumbai
# 19    Rain         city    mumbai
# 20   Sunny         city     paris
# 21  Cloudy         city     paris
# 22  Cloudy         city     paris
# 23  Cloudy         city     paris
# 24    Rain  temperature        32
# 25   Sunny  temperature        36
# ...
