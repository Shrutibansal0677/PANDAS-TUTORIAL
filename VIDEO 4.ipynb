# %%
import pandas as pd

# %%
df= pd.read_csv('C:/Users/HP/Downloads/weather_data.csv')

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[['temperature', 'day']]
# Out:
#    temperature       day
# 0           32  1/1/2017
# 1           35  1/2/2017
# 2           28  1/3/2017
# 3           24  1/4/2017
# 4           32  1/5/2017
# 5           31  1/6/2017

# %%
df[df.day=='1/4/2017']
# Out:
#         day  temperature  windspeed event
# 3  1/4/2017           24          7  Snow

# %%
df[['day', 'temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day']]
# Out:
#         day
# 0  1/1/2017
# 1  1/2/2017
# 2  1/3/2017
# 3  1/4/2017
# 4  1/5/2017
# 5  1/6/2017

# %%
df2= pd.read_csv("stock_data.csv", header=None, names=['namaste', 'namaskaram', 'peri pona','hi', 'hello' ]) 
#skiprows=1, header=1} to skip the header
df2
# Out:
#    namaste     namaskaram peri pona     hi          hello
# 0  tickers            eps   revenue  price         people
# 1    GOOGL          27.82        87    845     larry page
# 2      WMT           4.61       484     65           n.a.
# 3     MSFT             -1        85     64     bill gates
# 4     RIL   not available        50   1023  mukesh ambani
# 5     TATA            5.6        -1   n.a.     ratan tata

# %%
df3= pd.read_csv("stock_data.csv", nrows=100)
df3
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df4 = pd.read_csv("stock_data.csv", na_values=['not available', 'n.a.'])
df4
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df5 = pd.read_csv("stock_data.csv", na_values={
    'tickers':['not available', 'n.a.'],
    'eps': ['not available', 'n.a.'],
    'revenue':['not available', 'n.a.', '-1'],
    'price': ['not available', 'n.a.'],
    'people' : ['not available', 'n.a.']
})
df5
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df6= pd.read_csv("stock_data.csv", na_values={
    'eps': ['not available', 'n.a.'],
    'revenue':['not available', 'n.a.', '-1'],
    
})
df6
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65           n.a.
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
#to print particular columns
df7= pd.read_csv("stock_data.csv", columns=['eps', 'price']) #columns do not help to read particular columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 #to print particular columns
# ----> 2 df7= pd.read_csv("stock_data.csv", columns=['eps', 'price'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'columns'

# %% [markdown]
# # write to csv file

# %%
df3.to_csv('newfile2.csv')

# %%
df3.to_csv('newfile3.csv', index=False, columns=['price', 'tickers'])

# %%
df3.to_csv('newfile4.csv', header= None)
# header = 1 / skiprows = 1 is not used to skip header in to_csv

# %% [markdown]
# #  to read excel file

# %%
dfe= pd.read_excel('stock_data.xlsx') 
dfe
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
dfe2= pd.read_excel('stock_data.xlsx', 'Sheet1')
dfe2
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convertocell(cell):
    if cell=='n.a.':
        return ('sam walton')
    return cell

dfe3= pd.read_excel('stock_data.xlsx', 'Sheet1', converters={
    'people': convertocell
})
dfe3
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65     sam walton
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# # write to excel file

# %%
dfe2.to_excel('newexcel.xlsx', sheet_name='Stocks', index= False, startrow=15, startcol=7)

# %%
with pd.ExcelWriter("both.xlsx") as writer:
    df.to_excel(writer, sheet_name='WEATHER'),
    df3.to_excel(writer, sheet_name='Stocsk' )
